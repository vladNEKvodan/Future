# %% [markdown]
# Максаев Владислав Андреевич ПИ20-1

# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Задание 3: i

# %%
df.shape[0]
# Out:
# 891

# %% [markdown]
# Задание 3: ii

# %%
df.shape[1]
# Out:
# 12

# %% [markdown]
# Задание 3: iii

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# Задание 3: IV

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Задание 3: V

# %%
df.nunique()
# Out:
# Номер пассажира    891
# Выжил                2
# Пкласс               3
# Имя                891
# Пол                  2
# Возраст             89
# СибСп                7
# Парч                 7
# Билет              681
# Оплата             248
# Кабина             148
# Загрузка             3
# dtype: int64

# %%
df.nunique().sum()
# Out:
# 2972

# %% [markdown]
# Задание 4:

# %%
df.drop_duplicates()
# Out:
#      Номер пассажира  Выжил  Пкласс  \
# 0                  1      0       3
# 1                  2      1       1
# 2                  3      1       3
# 3                  4      1       1
# 4                  5      0       3
# ..               ...    ...     ...
# 886              887      0       2
# 887              888      1       1
# 888              889      0       3
# 889              890      1       1
# 890              891      0       3
#
#                                                    Имя     Пол      Возраст  \
# 0                              Braund, Mr. Owen Harris    male  2000.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  1984.000000
# 2                               Heikkinen, Miss. Laina  female  1996.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  1987.000000
# 4                             Allen, Mr. William Henry    male  1987.000000
# ...

# %% [markdown]
# Задание 5:

# %%
df['Age'] = 2022 - df['Age']
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex     Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  2000.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  1984.0      1
# 2                             Heikkinen, Miss. Laina  female  1996.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  1987.0      1
# 4                           Allen, Mr. William Henry    male  1987.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %% [markdown]
# Задание 6:

# %%
df.rename(columns={'PassengerId': 'Номер пассажира', 'Survived': 'Выжил', 'Pclass': 'Пкласс', 'Name': 'Имя', 'Sex': 'Пол', 'Age': 'Возраст', 'SibSp': 'СибСп', 'Parch': 'Парч', 'Ticket': 'Билет', 'Fare': 'Оплата', 'Cabin': 'Кабина', 'Embarked': 'Загрузка'}, inplace=True)
df.head()
# Out:
#    Номер пассажира  Выжил  Пкласс  \
# 0                1      0       3
# 1                2      1       1
# 2                3      1       3
# 3                4      1       1
# 4                5      0       3
#
#                                                  Имя     Пол  Возраст  СибСп  \
# 0                            Braund, Mr. Owen Harris    male   2000.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   1984.0      1
# 2                             Heikkinen, Miss. Laina  female   1996.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   1987.0      1
# 4                           Allen, Mr. William Henry    male   1987.0      0
#
#    Парч             Билет   Оплата Кабина Загрузка
# 0     0         A/5 21171   7.2500    NaN        S
# 1     0          PC 17599  71.2833    C85        C
# 2     0  STON/O2. 3101282   7.9250    NaN        S
# 3     0            113803  53.1000   C123        S
# ...

# %% [markdown]
# Задание 7:

# %%
sr = df['Возраст'].mean
sr
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0      2000.000000
# 1      1984.000000
# 2      1996.000000
# 3      1987.000000
# 4      1987.000000
#           ...
# 886    1995.000000
# 887    2003.000000
# 888    1992.300882
# 889    1996.000000
# 890    1990.000000
# Name: Возраст, Length: 891, dtype: float64>

# %%
df['Возраст'] = df['Возраст'].fillna(value = df['Возраст'].mean())
df.isna()
# Out:
#      Номер пассажира  Выжил  Pclass    Имя    Пол  Возраст  СибСп   Парч  \
# 0              False  False   False  False  False    False  False  False
# 1              False  False   False  False  False    False  False  False
# 2              False  False   False  False  False    False  False  False
# 3              False  False   False  False  False    False  False  False
# 4              False  False   False  False  False    False  False  False
# ..               ...    ...     ...    ...    ...      ...    ...    ...
# 886            False  False   False  False  False    False  False  False
# 887            False  False   False  False  False    False  False  False
# 888            False  False   False  False  False    False  False  False
# 889            False  False   False  False  False    False  False  False
# 890            False  False   False  False  False    False  False  False
#
#      Билет  Оплата  Кабина  Загрузка
# 0    False   False    True     False
# ...

# %%
df['Кабина'].value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: Кабина, Length: 147, dtype: int64

# %%
df['Кабина'] = df['Кабина'].fillna(value = 'B98')
df.isna()
# Out:
#      Номер пассажира  Выжил  Пкласс    Имя    Пол  Возраст  СибСп   Парч  \
# 0              False  False   False  False  False    False  False  False
# 1              False  False   False  False  False    False  False  False
# 2              False  False   False  False  False    False  False  False
# 3              False  False   False  False  False    False  False  False
# 4              False  False   False  False  False    False  False  False
# ..               ...    ...     ...    ...    ...      ...    ...    ...
# 886            False  False   False  False  False    False  False  False
# 887            False  False   False  False  False    False  False  False
# 888            False  False   False  False  False    False  False  False
# 889            False  False   False  False  False    False  False  False
# 890            False  False   False  False  False    False  False  False
#
#      Билет  Оплата  Кабина  Загрузка
# 0    False   False   False     False
# ...

# %% [markdown]
# Задание 8:

# %%
df.to_csv('train_2.csv')

# %% [markdown]
# Задание 9:

# %%
df.to_excel('train_2.xlsx')
df
# Out:
#      Номер пассажира  Выжил  Пкласс  \
# 0                  1      0       3
# 1                  2      1       1
# 2                  3      1       3
# 3                  4      1       1
# 4                  5      0       3
# ..               ...    ...     ...
# 886              887      0       2
# 887              888      1       1
# 888              889      0       3
# 889              890      1       1
# 890              891      0       3
#
#                                                    Имя     Пол      Возраст  \
# 0                              Braund, Mr. Owen Harris    male  2000.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  1984.000000
# 2                               Heikkinen, Miss. Laina  female  1996.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  1987.000000
# 4                             Allen, Mr. William Henry    male  1987.000000
# ...

# %% [markdown]
# Задание 10:

# %%
df_2 = pd.read_excel('train_2.xlsx')
df_2.head()
# Out:
#    Unnamed: 0  Номер пассажира  Выжил  Пкласс  \
# 0           0                1      0       3
# 1           1                2      1       1
# 2           2                3      1       3
# 3           3                4      1       1
# 4           4                5      0       3
#
#                                                  Имя     Пол  Возраст  СибСп  \
# 0                            Braund, Mr. Owen Harris    male   2000.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   1984.0      1
# 2                             Heikkinen, Miss. Laina  female   1996.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   1987.0      1
# 4                           Allen, Mr. William Henry    male   1987.0      0
#
#    Парч             Билет   Оплата Кабина Загрузка
# 0     0         A/5 21171   7.2500    B98        S
# 1     0          PC 17599  71.2833    C85        C
# 2     0  STON/O2. 3101282   7.9250    B98        S
# ...
